# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.backtesting import BacktestingEngine

backtesting = BacktestingEngine(root_path=root_path, load_cached_data=False)

# %%
from hummingbot.strategy_v2.utils.distributions import Distributions
from controllers.market_making.pmm_simple import PMMSimpleConfig
from hummingbot.strategy_v2.executors.position_executor.data_types import TrailingStop
import datetime
from decimal import Decimal

# Controller configuration
connector_name = "binance"
trading_pair = "POL-USDT"
total_amount_quote = 1000
take_profit = 0.02
stop_loss = 0.01
trailing_stop_activation_price = 0.015
trailing_stop_trailing_delta = 0.07
time_limit = 60 * 60 * 2
executor_refresh_time = 60 * 6
cooldown_time = 600

# order book levels
sell_order_book_levels = 4
buy_order_book_levels = 4

# Backtesting configuration
start = int(datetime.datetime(2025, 5, 25).timestamp())
end = int(datetime.datetime(2025, 5, 26).timestamp())
backtesting_resolution = "1m"

# Creating the instance of the configuration and the controller
config = PMMSimpleConfig(
    connector_name=connector_name,
    trading_pair=trading_pair,
    sell_spreads=Distributions.arithmetic(sell_order_book_levels, 0.001, 0.001),
    buy_spreads=Distributions.arithmetic(buy_order_book_levels, 0.001, 0.001),
    total_amount_quote=Decimal(total_amount_quote),
    take_profit=Decimal(take_profit),
    stop_loss=Decimal(stop_loss),
    trailing_stop=TrailingStop(activation_price=Decimal(trailing_stop_activation_price), trailing_delta=Decimal(trailing_stop_trailing_delta)),
    time_limit=time_limit,
    cooldown_time=cooldown_time,
    executor_refresh_time=executor_refresh_time,
    buy_amounts_pct = [0.1, 0.1, 0.3, 0.5],
    sell_amounts_pct = [0.1, 0.1, 0.3, 0.5]
)

# %%
# Running the backtesting this will output a backtesting result object that has built in methods to visualize the results

backtesting_result = await backtesting.run_backtesting(config, start, end, backtesting_resolution)

# %%
backtesting_result.controller_config
# Out:
# PMMSimpleConfig(id=None, controller_name='pmm_simple', controller_type='market_making', total_amount_quote=Decimal('1000'), manual_kill_switch=False, candles_config=[], connector_name='binance', trading_pair='POL-USDT', buy_spreads=[0.001, 0.002, 0.003, 0.004], sell_spreads=[0.001, 0.002, 0.003, 0.004], buy_amounts_pct=[Decimal('0.1'), Decimal('0.1'), Decimal('0.3'), Decimal('0.5')], sell_amounts_pct=[Decimal('0.1'), Decimal('0.1'), Decimal('0.3'), Decimal('0.5')], executor_refresh_time=360, cooldown_time=600, leverage=20, position_mode='HEDGE', stop_loss=Decimal('0.01000000000000000020816681711721685132943093776702880859375'), take_profit=Decimal('0.0200000000000000004163336342344337026588618755340576171875'), time_limit=7200, take_profit_order_type=<OrderType.LIMIT: 2>, trailing_stop=TrailingStop(activation_price=Decimal('0.01499999999999999944488848768742172978818416595458984375'), trailing_delta=Decimal('0.070000000000000006661338147750939242541790008544921875')))

# %%
# Running the backtesting this will output a backtesting result object that has built in methods to visualize the results

# backtesting_result = await backtesting.run_backtesting(config, start, end, backtesting_resolution)

# %%
# Running the backtesting this will output a backtesting result object that has built in methods to visualize the results

# backtesting_result = await backtesting.run_backtesting(config, start, end, backtesting_resolution)

# %%
# Let's see what is inside the backtesting results
print(backtesting_result.get_results_summary())
backtesting_result.get_backtesting_figure()
# Out:
# Net PNL: $-11.60 (-1.16%) | Max Drawdown: $-11.97 (-1.20%)
# Total Volume ($): 13500.49 | Sharpe Ratio: -1.43 | Profit Factor: 0.52
# Total Executors: 559 | Accuracy Long: 0.43 | Accuracy Short: 0.44
# Close Types: Take Profit: 0 | Stop Loss: 15 | Time Limit: 59 |
#              Trailing Stop: 0 | Early Stop: 485

# %%
# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
import pandas as pd

executors_df = backtesting_result.executors_df
executors_df.head()
# Out:
#                                              id  timestamp               type  \
# 0  EYoX9fS5aPhYHiQ53L7yG1U4GhdURxoouwuERF8XvsCF 1748124000  position_executor
# 1  7jNZWSmZJDvjUFe41UZQn3VGePiPjCEaWmzV4LLc78u1 1748124000  position_executor
# 2  CuD2NNg4SojYXdSo4efNACSNZ3fw1ddS17eWYy8f2R96 1748124000  position_executor
# 3  2H6ibB15LVDm9bUKyqFBHgKGsYqerrJNS1DvZGMaoQpE 1748124000  position_executor
# 4   ebD434vu64w65gofgK1vgReZD4XykSp2vkvG3B38Q2B 1748124000  position_executor
#
#                       status  \
# 0  RunnableStatus.TERMINATED
# 1  RunnableStatus.TERMINATED
# 2  RunnableStatus.TERMINATED
# 3  RunnableStatus.TERMINATED
# 4  RunnableStatus.TERMINATED
#
#                                               config net_pnl_pct  \
# 0  {'id': 'EYoX9fS5aPhYHiQ53L7yG1U4GhdURxoouwuERF...           0
# 1  {'id': '7jNZWSmZJDvjUFe41UZQn3VGePiPjCEaWmzV4L...           0
# 2  {'id': 'CuD2NNg4SojYXdSo4efNACSNZ3fw1ddS17eWYy...           0
# 3  {'id': '2H6ibB15LVDm9bUKyqFBHgKGsYqerrJNS1DvZG...           0
# 4  {'id': 'ebD434vu64w65gofgK1vgReZD4XykSp2vkvG3B...           0
#
#   net_pnl_quote cum_fees_quote filled_amount_quote  is_active  is_trading  \
# 0             0              0                   0      False       False
# 1             0              0                   0      False       False
# 2             0              0                   0      False       False
# 3             0              0                   0      False       False
# 4             0              0                   0      False       False
#
#                                          custom_info  close_timestamp  \
# 0  {'close_price': 0.2324, 'level_id': 'buy_3', '...       1748124420
# 1  {'close_price': 0.2324, 'level_id': 'sell_0', ...       1748124420
# 2  {'close_price': 0.2324, 'level_id': 'sell_1', ...       1748124420
# 3  {'close_price': 0.2324, 'level_id': 'sell_2', ...       1748124420
# 4  {'close_price': 0.2324, 'level_id': 'sell_3', ...       1748124420
#
#              close_type controller_id  side
# 0  CloseType.EARLY_STOP          None   BUY
# 1  CloseType.EARLY_STOP          None  SELL
# 2  CloseType.EARLY_STOP          None  SELL
# 3  CloseType.EARLY_STOP          None  SELL
# 4  CloseType.EARLY_STOP          None  SELL

# %% [markdown]
# ### Backtesting Analysis

# %% [markdown]
# ### Scatter of PNL per Trade
# This bar chart illustrates the PNL for each individual trade. Positive PNLs are shown in green and negative PNLs in red, providing a clear view of profitable vs. unprofitable trades.

# %%
import plotly.express as px

# Create a new column for profitability
executors_df['profitable'] = executors_df['net_pnl_quote'] > 0

# Create the scatter plot
fig = px.scatter(
    executors_df,
    x="timestamp",
    y='net_pnl_quote',
    title='PNL per Trade',
    color='profitable',
    color_discrete_map={True: 'green', False: 'red'},
    labels={'timestamp': 'Timestamp', 'net_pnl_quote': 'Net PNL (Quote)'},
    hover_data=['filled_amount_quote', 'side']
)

# Customize the layout
fig.update_layout(
    xaxis_title="Timestamp",
    yaxis_title="Net PNL (Quote)",
    legend_title="Profitable",
    font=dict(size=12, color="white"),
    showlegend=False,
    plot_bgcolor='rgba(0,0,0,0.8)',  # Dark background
    paper_bgcolor='rgba(0,0,0,0.8)',  # Dark background for the entire plot area
    xaxis=dict(gridcolor="gray"),
    yaxis=dict(gridcolor="gray")
)

# Add a horizontal line at y=0 to clearly separate profits and losses
fig.add_hline(y=0, line_dash="dash", line_color="lightgray")

# Show the plot
# fig.show()

# %% [markdown]
# ### Histogram of PNL Distribution
# The histogram displays the distribution of PNL values across all trades. It helps in understanding the frequency and range of profit and loss outcomes.

# %%
fig = px.histogram(executors_df, x='net_pnl_quote', title='PNL Distribution')
fig.show()
